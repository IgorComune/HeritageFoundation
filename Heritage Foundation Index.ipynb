# %%
#importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
#reading the excel file

heritage = pd.read_excel('index2021_data.xls')
heritage
# Out:
#      CountryID Country Name      WEBNAME                        Region  \
# 0            1  Afghanistan  Afghanistan                  Asia-Pacific
# 1            2      Albania      Albania                        Europe
# 2            3      Algeria      Algeria  Middle East and North Africa
# 3            4       Angola       Angola            Sub-Saharan Africa
# 4            5    Argentina    Argentina                      Americas
# ..         ...          ...          ...                           ...
# 179        179    Venezuela    Venezuela                      Americas
# 180        180      Vietnam      Vietnam                  Asia-Pacific
# 181        181        Yemen        Yemen  Middle East and North Africa
# 182        182       Zambia       Zambia            Sub-Saharan Africa
# 183        183     Zimbabwe     Zimbabwe            Sub-Saharan Africa
#
#      World Rank  Region Rank  2021 Score  Property Rights  \
# ...

# %%
# exploring the data set shape
heritage.shape
# Out:
# (184, 34)

# %%
#exploring the data types - no need to convert any data type column
heritage.dtypes
# Out:
# CountryID                        int64
# Country Name                    object
# WEBNAME                         object
# Region                          object
# World Rank                     float64
# Region Rank                    float64
# 2021 Score                     float64
# Property Rights                float64
# Judical Effectiveness          float64
# Government Integrity           float64
# Tax Burden                     float64
# Gov't Spending                 float64
# Fiscal Health                  float64
# Business Freedom               float64
# Labor Freedom                  float64
# Monetary Freedom               float64
# Trade Freedom                  float64
# Investment Freedom             float64
# Financial Freedom              float64
# Tariff Rate (%)                float64
# Income Tax Rate (%)            float64
# Corporate Tax Rate (%)         float64
# Tax Burden % of GDP            float64
# Gov't Expenditure % of GDP     float64
# ...

# %% [markdown]
# # working with the data frame

# %%
# deleting country id and webname

del heritage['CountryID'], heritage['WEBNAME'], heritage['Country']

# %%
# the two columns were deleted
heritage.shape
# Out:
# (184, 31)

# %%
# setting Country Name as index

heritage.set_index('Country Name')
# Out:
#                                     Region  World Rank  Region Rank  \
# Country Name
# Afghanistan                   Asia-Pacific       146.0         33.0
# Albania                             Europe        66.0         35.0
# Algeria       Middle East and North Africa       162.0         13.0
# Angola                  Sub-Saharan Africa       140.0         30.0
# Argentina                         Americas       148.0         26.0
# ...                                    ...         ...          ...
# Venezuela                         Americas       177.0         32.0
# Vietnam                       Asia-Pacific        90.0         17.0
# Yemen         Middle East and North Africa         NaN          NaN
# Zambia                  Sub-Saharan Africa       159.0         39.0
# Zimbabwe                Sub-Saharan Africa       174.0         46.0
#
#               2021 Score  Property Rights  Judical Effectiveness  \
# Country Name
# ...

# %%
contries_nan = heritage[heritage.isna().any(axis=1)]
contries_nan
# Out:
#       Country Name                        Region  World Rank  Region Rank  \
# 42            Cuba                      Americas       176.0         31.0
# 47        Dominica                      Americas       147.0         25.0
# 77            Iraq  Middle East and North Africa         NaN          NaN
# 86        Kiribati                  Asia-Pacific       171.0         39.0
# 87   Korea, North                   Asia-Pacific       178.0         40.0
# 97           Libya  Middle East and North Africa         NaN          NaN
# 98   Liechtenstein                        Europe         NaN          NaN
# 145     Seychelles            Sub-Saharan Africa        60.0          4.0
# 151        Somalia            Sub-Saharan Africa         NaN          NaN
# 159          Syria  Middle East and North Africa         NaN          NaN
# 181          Yemen  Middle East and North Africa         NaN          NaN
#
#      2021 Score  Property Rights  Judical Effectiveness  Government Integrity  \
# ...

# %%
len(contries_nan)
# Out:
# 11

# %%
heritage.shape
# Out:
# (184, 31)

# %%
# the 11 countries with NaN values was dropped from 
# the main data frame "heritage" and they are stored in the variable "contries_nan"
heritage.dropna(inplace=True)

# %%
#first view of the clean data and setting again the index
heritage.set_index('Country Name')
# Out:
#                                     Region  World Rank  Region Rank  \
# Country Name
# Afghanistan                   Asia-Pacific       146.0         33.0
# Albania                             Europe        66.0         35.0
# Algeria       Middle East and North Africa       162.0         13.0
# Angola                  Sub-Saharan Africa       140.0         30.0
# Argentina                         Americas       148.0         26.0
# ...                                    ...         ...          ...
# Vanuatu                       Asia-Pacific        97.0         18.0
# Venezuela                         Americas       177.0         32.0
# Vietnam                       Asia-Pacific        90.0         17.0
# Zambia                  Sub-Saharan Africa       159.0         39.0
# Zimbabwe                Sub-Saharan Africa       174.0         46.0
#
#               2021 Score  Property Rights  Judical Effectiveness  \
# Country Name
# ...

# %%
heritage2 = heritage.set_index('Country Name')

# %% [markdown]
# # gathering data

# %%
#counting the number of countries grouping by its region
graf1 = heritage2.groupby(['Region'])['World Rank'].count()
graf1
# Out:
# Region
# Americas                        30
# Asia-Pacific                    38
# Europe                          45
# Middle East and North Africa    14
# Sub-Saharan Africa              46
# Name: World Rank, dtype: int64

# %%
all_countries = heritage2.groupby(['Region'])['World Rank'].count()
all_countries
# Out:
# Region
# Americas                        30
# Asia-Pacific                    38
# Europe                          45
# Middle East and North Africa    14
# Sub-Saharan Africa              46
# Name: World Rank, dtype: int64

# %%
graf1.plot.bar(rot=15, color='#822b82')
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
totNcountries = heritage2.shape[0]
ameNcoutnries = heritage2.groupby(['Region'])['World Rank'].count()[0]
apNcoutnries = heritage2.groupby(['Region'])['World Rank'].count()[1]
euNcoutnries = heritage2.groupby(['Region'])['World Rank'].count()[2]
mnaNcoutnries = heritage2.groupby(['Region'])['World Rank'].count()[3]
ssaNcoutnries = heritage2.groupby(['Region'])['World Rank'].count()[4]

# %%
#organizing the number of countries by region is a dict
countriesdict = {'Americas': ameNcoutnries,
            'Asia-Pacific':apNcoutnries,
            'Europe':euNcoutnries,
            'Middle East and North Africa':mnaNcoutnries,
            'Sub-Saharan Africa':ssaNcoutnries,}
countriesdict
# Out:
# {'Americas': 30,
#  'Asia-Pacific': 38,
#  'Europe': 45,
#  'Middle East and North Africa': 14,
#  'Sub-Saharan Africa': 46}

# %%
r_rank = heritage2.groupby(['Region'])['World Rank'].mean().sort_values()
r_rank
# Out:
# Region
# Europe                           44.466667
# Middle East and North Africa     85.857143
# Americas                         89.766667
# Asia-Pacific                     92.684211
# Sub-Saharan Africa              125.673913
# Name: World Rank, dtype: float64

# %%
heritage2.groupby(['Region'])['World Rank'].mean().mean()
# Out:
# 87.68971995205405

# %%
r_inflation = heritage2.groupby(['Region'])['Inflation (%)'].mean().sort_values()
r_inflation
# Out:
# Region
# Europe                            2.390889
# Asia-Pacific                      3.245579
# Middle East and North Africa      4.723143
# Sub-Saharan Africa               10.590500
# Americas                        668.160400
# Name: Inflation (%), dtype: float64

# %%
r_unemployment = heritage2.groupby(['Region'])['Unemployment (%)'].mean().sort_values()
r_unemployment
# Out:
# Region
# Asia-Pacific                    4.518421
# Middle East and North Africa    6.978571
# Sub-Saharan Africa              7.565217
# Europe                          7.864444
# Americas                        8.353333
# Name: Unemployment (%), dtype: float64

# %%
r_gdp = heritage2.groupby(['Region'])['GDP per Capita (PPP)'].mean().sort_values()
r_gdp
# Out:
# Region
# Sub-Saharan Africa               4978.500090
# Americas                        18340.411191
# Asia-Pacific                    18608.471948
# Middle East and North Africa    33357.502617
# Europe                          39454.894415
# Name: GDP per Capita (PPP), dtype: float64

# %%
r_fdi = heritage2.groupby(['Region'])['FDI Inflow (Millions)'].mean().sort_values()
r_fdi
# Out:
# Region
# Sub-Saharan Africa                694.388316
# Middle East and North Africa     3951.413491
# Europe                          10768.288769
# Asia-Pacific                    11554.098669
# Americas                        15392.638341
# Name: FDI Inflow (Millions), dtype: float64

# %%
df1 = pd.DataFrame([r_rank,r_inflation,r_unemployment,r_gdp])
df1_transposed = df1.transpose().round(decimals=0)
df1_transposed
# Out:
#                               World Rank  Inflation (%)  Unemployment (%)  \
# Europe                              44.0            2.0               8.0
# Middle East and North Africa        86.0            5.0               7.0
# Americas                            90.0          668.0               8.0
# Asia-Pacific                        93.0            3.0               5.0
# Sub-Saharan Africa                 126.0           11.0               8.0
#
#                               GDP per Capita (PPP)
# Europe                                     39455.0
# Middle East and North Africa               33358.0
# Americas                                   18340.0
# Asia-Pacific                               18608.0
# Sub-Saharan Africa                          4979.0

# %% [markdown]
# # investigating inflation outlier

# %%
heritage2
# Out:
#                                     Region  World Rank  Region Rank  \
# Country Name
# Afghanistan                   Asia-Pacific       146.0         33.0
# Albania                             Europe        66.0         35.0
# Algeria       Middle East and North Africa       162.0         13.0
# Angola                  Sub-Saharan Africa       140.0         30.0
# Argentina                         Americas       148.0         26.0
# ...                                    ...         ...          ...
# Vanuatu                       Asia-Pacific        97.0         18.0
# Venezuela                         Americas       177.0         32.0
# Vietnam                       Asia-Pacific        90.0         17.0
# Zambia                  Sub-Saharan Africa       159.0         39.0
# Zimbabwe                Sub-Saharan Africa       174.0         46.0
#
#               2021 Score  Property Rights  Judical Effectiveness  \
# Country Name
# ...

# %%
#filtering countries of america and storing them into a new variable called df_americas
df_americas = heritage2.loc[heritage2['Region'] == 'Americas']
df_americas
# Out:
#                                     Region  World Rank  Region Rank  \
# Country Name
# Argentina                         Americas       148.0         26.0
# Bahamas                           Americas        70.0         13.0
# Barbados                          Americas        67.0         12.0
# Belize                            Americas       114.0         21.0
# Bolivia                           Americas       172.0         30.0
# Brazil                            Americas       143.0         24.0
# Canada                            Americas         9.0          1.0
# Chile                             Americas        19.0          2.0
# Colombia                          Americas        49.0          6.0
# Costa Rica                        Americas        72.0         14.0
# Dominican Republic                Americas        88.0         17.0
# Ecuador                           Americas       149.0         27.0
# El Salvador                       Americas        94.0         18.0
# ...

# %%
#sorting values by inflation and bringing only inflation by country name
americas_inflation = df_americas.sort_values('Inflation (%)', ascending=False)['Inflation (%)']
americas_inflation
# Out:
# Country Name
# Venezuela                           19906.020
# Argentina                              53.548
# Haiti                                  17.346
# Uruguay                                 7.882
# Nicaragua                               5.376
# Suriname                                4.392
# Honduras                                4.365
# Barbados                                4.100
# Jamaica                                 3.910
# Brazil                                  3.733
# Guatemala                               3.700
# Mexico                                  3.635
# Colombia                                3.521
# Paraguay                                2.757
# Chile                                   2.253
# Peru                                    2.136
# Costa Rica                              2.097
# Guyana                                  2.092
# Canada                                  1.949
# Bolivia                                 1.839
# ...

# %%
#excluding the Venezuela outlier value
americas_inflation.drop('Venezuela',inplace=True)

# %%
#americas inflation average without Venezuela.
americas_inflation.mean()
# Out:
# 4.78593103448276

# %%
df1_transposed['Inflation (%)'][2] = americas_inflation.mean()

# %%
df1_transposed['Inflation (%)'].mean()
# Out:
# 5.157186206896553

# %%
df_filter = df1_transposed[['World Rank','GDP per Capita (PPP)']]
df_filter
# Out:
#                               World Rank  GDP per Capita (PPP)
# Europe                              44.0               39455.0
# Middle East and North Africa        86.0               33358.0
# Americas                            90.0               18340.0
# Asia-Pacific                        93.0               18608.0
# Sub-Saharan Africa                 126.0                4979.0

# %%
heritage2
# Out:
#                                     Region  World Rank  Region Rank  \
# Country Name
# Afghanistan                   Asia-Pacific       146.0         33.0
# Albania                             Europe        66.0         35.0
# Algeria       Middle East and North Africa       162.0         13.0
# Angola                  Sub-Saharan Africa       140.0         30.0
# Argentina                         Americas       148.0         26.0
# ...                                    ...         ...          ...
# Vanuatu                       Asia-Pacific        97.0         18.0
# Venezuela                         Americas       177.0         32.0
# Vietnam                       Asia-Pacific        90.0         17.0
# Zambia                  Sub-Saharan Africa       159.0         39.0
# Zimbabwe                Sub-Saharan Africa       174.0         46.0
#
#               2021 Score  Property Rights  Judical Effectiveness  \
# Country Name
# ...

# %%
countries = heritage2[['World Rank','GDP per Capita (PPP)']]
countries_sorted = countries.sort_values('World Rank')
countries_sorted
# Out:
#               World Rank  GDP per Capita (PPP)
# Country Name
# Singapore            1.0         101375.775311
# New Zealand          2.0          43952.548428
# Australia            3.0          53320.269043
# Switzerland          4.0          70989.258126
# Ireland              5.0          88240.901029
# ...                  ...                   ...
# Bolivia            172.0           9086.060696
# Eritrea            173.0           1710.000000
# Zimbabwe           174.0           2953.484113
# Sudan              175.0           4122.526685
# Venezuela          177.0           5990.000000
#
# [173 rows x 2 columns]

# %%
sns.relplot(data=countries_sorted, x='World Rank',y='GDP per Capita (PPP)')

# %%
countries_sorted.corr(method='pearson')
# Out:
#                       World Rank  GDP per Capita (PPP)
# World Rank              1.000000             -0.726296
# GDP per Capita (PPP)   -0.726296              1.000000

# %%
sns.lmplot(data=countries_sorted, x='World Rank',y='GDP per Capita (PPP)', legend=True)

# %% [markdown]
# # sub20k investigation

# %%
heritage2
# Out:
#                                     Region  World Rank  Region Rank  \
# Country Name
# Afghanistan                   Asia-Pacific       146.0         33.0
# Albania                             Europe        66.0         35.0
# Algeria       Middle East and North Africa       162.0         13.0
# Angola                  Sub-Saharan Africa       140.0         30.0
# Argentina                         Americas       148.0         26.0
# ...                                    ...         ...          ...
# Vanuatu                       Asia-Pacific        97.0         18.0
# Venezuela                         Americas       177.0         32.0
# Vietnam                       Asia-Pacific        90.0         17.0
# Zambia                  Sub-Saharan Africa       159.0         39.0
# Zimbabwe                Sub-Saharan Africa       174.0         46.0
#
#               2021 Score  Property Rights  Judical Effectiveness  \
# Country Name
# ...

# %%
sub20k = heritage2.loc[heritage2['GDP per Capita (PPP)'] < 20000]['GDP per Capita (PPP)'].sort_values()
sub20k.tail(50)
# Out:
# Country Name
# Laos                                 8150.752426
# Vietnam                              8374.444328
# Guatemala                            8995.537873
# Eswatini                             9048.178922
# Bolivia                              9086.060696
# El Salvador                          9139.706334
# Philippines                          9277.374369
# Namibia                             10036.592458
# Guyana                              10104.701191
# Jamaica                             10166.062775
# Jordan                              10316.609095
# Tunisia                             11201.343758
# Algeria                             11820.087684
# Kosovo                              11838.880995
# Ecuador                             11846.780558
# Egypt                               12250.780414
# Indonesia                           12301.752900
# Bhutan                              12390.000000
# Mongolia                            12819.948580
# ...

# %%
heritage3 = heritage2.reset_index()
heritage3
# Out:
#     Country Name                        Region  World Rank  Region Rank  \
# 0    Afghanistan                  Asia-Pacific       146.0         33.0
# 1        Albania                        Europe        66.0         35.0
# 2        Algeria  Middle East and North Africa       162.0         13.0
# 3         Angola            Sub-Saharan Africa       140.0         30.0
# 4      Argentina                      Americas       148.0         26.0
# ..           ...                           ...         ...          ...
# 168      Vanuatu                  Asia-Pacific        97.0         18.0
# 169    Venezuela                      Americas       177.0         32.0
# 170      Vietnam                  Asia-Pacific        90.0         17.0
# 171       Zambia            Sub-Saharan Africa       159.0         39.0
# 172     Zimbabwe            Sub-Saharan Africa       174.0         46.0
#
#      2021 Score  Property Rights  Judical Effectiveness  Government Integrity  \
# ...

# %%
#setting the indexes for group them
heritage3.set_index(['Region','Country Name'])
# Out:
#                                            World Rank  Region Rank  \
# Region                       Country Name
# Asia-Pacific                 Afghanistan        146.0         33.0
# Europe                       Albania             66.0         35.0
# Middle East and North Africa Algeria            162.0         13.0
# Sub-Saharan Africa           Angola             140.0         30.0
# Americas                     Argentina          148.0         26.0
# ...                                               ...          ...
# Asia-Pacific                 Vanuatu             97.0         18.0
# Americas                     Venezuela          177.0         32.0
# Asia-Pacific                 Vietnam             90.0         17.0
# Sub-Saharan Africa           Zambia             159.0         39.0
#                              Zimbabwe           174.0         46.0
#
#                                            2021 Score  Property Rights  \
# Region                       Country Name
# ...

# %%
#grouping countries by region
countries_region = heritage3.groupby(['Region','Country Name']).sum()
countries_region
# Out:
#                                  World Rank  Region Rank  2021 Score  \
# Region             Country Name
# Americas           Argentina          148.0         26.0        52.7
#                    Bahamas             70.0         13.0        64.6
#                    Barbados            67.0         12.0        65.0
#                    Belize             114.0         21.0        57.5
#                    Bolivia            172.0         30.0        42.7
# ...                                     ...          ...         ...
# Sub-Saharan Africa Tanzania            93.0          8.0        61.3
#                    Togo               113.0         18.0        57.5
#                    Uganda             106.0         14.0        58.6
#                    Zambia             159.0         39.0        50.4
#                    Zimbabwe           174.0         46.0        39.5
#
#                                  Property Rights  Judical Effectiveness  \
# ...

# %%
#all grouped countries by region below 20k PPP
countries20k = countries_region.loc[countries_region['GDP per Capita (PPP)'] < 20000]['GDP per Capita (PPP)']
countries20k
# Out:
# Region              Country Name
# Americas            Barbados        16286.979515
#                     Belize           7295.230136
#                     Bolivia          9086.060696
#                     Brazil          15258.850833
#                     Colombia        15643.731446
#                                         ...
# Sub-Saharan Africa  Tanzania         2770.681172
#                     Togo             1662.072345
#                     Uganda           2271.649424
#                     Zambia           3623.699395
#                     Zimbabwe         2953.484113
# Name: GDP per Capita (PPP), Length: 112, dtype: float64

# %%
countries20k.reset_index()
# Out:
#                  Region Country Name  GDP per Capita (PPP)
# 0              Americas     Barbados          16286.979515
# 1              Americas       Belize           7295.230136
# 2              Americas      Bolivia           9086.060696
# 3              Americas       Brazil          15258.850833
# 4              Americas     Colombia          15643.731446
# ..                  ...          ...                   ...
# 107  Sub-Saharan Africa     Tanzania           2770.681172
# 108  Sub-Saharan Africa         Togo           1662.072345
# 109  Sub-Saharan Africa       Uganda           2271.649424
# 110  Sub-Saharan Africa       Zambia           3623.699395
# 111  Sub-Saharan Africa     Zimbabwe           2953.484113
#
# [112 rows x 3 columns]

# %%
#countries
countries20k.groupby('Region').count()
# Out:
# Region
# Americas                        20
# Asia-Pacific                    29
# Europe                          11
# Middle East and North Africa     7
# Sub-Saharan Africa              45
# Name: GDP per Capita (PPP), dtype: int64

# %%
(112/173)*100
# Out:
# 64.73988439306359

# %%
sub20_countries = countries20k.groupby('Region').count()
sub20_countries
# Out:
# Region
# Americas                        20
# Asia-Pacific                    29
# Europe                          11
# Middle East and North Africa     7
# Sub-Saharan Africa              45
# Name: GDP per Capita (PPP), dtype: int64

# %%
countries_percentage = pd.DataFrame([all_countries, sub20_countries]).transpose()
countries_percentage
# Out:
#                               World Rank  GDP per Capita (PPP)
# Region
# Americas                              30                    20
# Asia-Pacific                          38                    29
# Europe                                45                    11
# Middle East and North Africa          14                     7
# Sub-Saharan Africa                    46                    45

# %%
countries_percentage['Percentage'] = countries_percentage['GDP per Capita (PPP)'] / countries_percentage['World Rank']

# %%
countries_percentage
# Out:
#                               World Rank  GDP per Capita (PPP)  Percentage
# Region
# Americas                              30                    20    0.666667
# Asia-Pacific                          38                    29    0.763158
# Europe                                45                    11    0.244444
# Middle East and North Africa          14                     7    0.500000
# Sub-Saharan Africa                    46                    45    0.978261

# %%
countries_percentage.columns = ['Nº of Countries', 'Nº Sub20k Countries','Percentage']

# %%
#percentage countries
countries_percentage.round(2).sort_values('Percentage')
# Out:
#                               Nº of Countries  Nº Sub20k Countries  Percentage
# Region
# Europe                                     45                   11        0.24
# Middle East and North Africa               14                    7        0.50
# Americas                                   30                   20        0.67
# Asia-Pacific                               38                   29        0.76
# Sub-Saharan Africa                         46                   45        0.98

# %% [markdown]
# # Investigating the Sub Heritage's Indexes - Correlation With PPP

# %%
#the dataset grouped by Region and its countries
countries_region.reset_index(inplace=True)

# %% [markdown]
# # Property Rights and PPP

# %%
rp_ppp = countries_region[['Region','Country Name','Property Rights','GDP per Capita (PPP)']]
rp_ppp
# Out:
#                  Region Country Name  Property Rights  GDP per Capita (PPP)
# 0              Americas    Argentina             46.1          22947.139795
# 1              Americas      Bahamas             48.1          37265.812102
# 2              Americas     Barbados             52.7          16286.979515
# 3              Americas       Belize             41.8           7295.230136
# 4              Americas      Bolivia             18.7           9086.060696
# ..                  ...          ...              ...                   ...
# 168  Sub-Saharan Africa     Tanzania             41.3           2770.681172
# 169  Sub-Saharan Africa         Togo             44.5           1662.072345
# 170  Sub-Saharan Africa       Uganda             44.8           2271.649424
# 171  Sub-Saharan Africa       Zambia             37.2           3623.699395
# 172  Sub-Saharan Africa     Zimbabwe             32.6           2953.484113
#
# [173 rows x 4 columns]

# %%
rp_ppp_table = rp_ppp.groupby('Region').mean().sort_values('Property Rights', ascending=False)
rp_ppp_table.round(2)
# Out:
#                               Property Rights  GDP per Capita (PPP)
# Region
# Europe                                  71.55              39454.89
# Middle East and North Africa            60.54              33357.50
# Asia-Pacific                            54.70              18608.47
# Americas                                49.06              18340.41
# Sub-Saharan Africa                      39.71               4978.50

# %%
sns.lmplot(data=rp_ppp, x='Property Rights',y='GDP per Capita (PPP)')
#sns.lmplot(data=countries_sorted, x='World Rank',y='GDP per Capita (PPP)', legend=True)

# %%
rp_ppp.corr(method='pearson')
# Out:
#                       Property Rights  GDP per Capita (PPP)
# Property Rights              1.000000              0.780896
# GDP per Capita (PPP)         0.780896              1.000000

# %% [markdown]
# # Judical Effectiveness x PPP

# %%
je_ppp = countries_region[['Region','Country Name','Judical Effectiveness','GDP per Capita (PPP)']]
je_ppp
# Out:
#                  Region Country Name  Judical Effectiveness  \
# 0              Americas    Argentina                   45.7
# 1              Americas      Bahamas                   45.7
# 2              Americas     Barbados                   49.7
# 3              Americas       Belize                   45.7
# 4              Americas      Bolivia                   11.0
# ..                  ...          ...                    ...
# 168  Sub-Saharan Africa     Tanzania                   40.2
# 169  Sub-Saharan Africa         Togo                   28.2
# 170  Sub-Saharan Africa       Uganda                   36.5
# 171  Sub-Saharan Africa       Zambia                   26.2
# 172  Sub-Saharan Africa     Zimbabwe                   32.0
#
#      GDP per Capita (PPP)
# 0            22947.139795
# 1            37265.812102
# 2            16286.979515
# 3             7295.230136
# 4             9086.060696
# ..                    ...
# 168           2770.681172
# ...

# %%
je_ppp_table = je_ppp.groupby('Region').mean().sort_values('Judical Effectiveness', ascending=False)
je_ppp_table.round(2)
# Out:
#                               Judical Effectiveness  GDP per Capita (PPP)
# Region
# Europe                                        60.02              39454.89
# Middle East and North Africa                  56.48              33357.50
# Asia-Pacific                                  45.80              18608.47
# Americas                                      41.08              18340.41
# Sub-Saharan Africa                            36.33               4978.50

# %%
sns.lmplot(data=je_ppp, x='Judical Effectiveness',y='GDP per Capita (PPP)')

# %%
je_ppp.corr(method='pearson')
# Out:
#                        Judical Effectiveness  GDP per Capita (PPP)
# Judical Effectiveness               1.000000              0.720092
# GDP per Capita (PPP)                0.720092              1.000000

# %% [markdown]
# # Government Integrity x PPP

# %%
gi_ppp = countries_region[['Region','Country Name','Government Integrity','GDP per Capita (PPP)']]
gi_ppp
# Out:
#                  Region Country Name  Government Integrity  \
# 0              Americas    Argentina                  54.0
# 1              Americas      Bahamas                  47.5
# 2              Americas     Barbados                  50.2
# 3              Americas       Belize                  36.3
# 4              Americas      Bolivia                  25.9
# ..                  ...          ...                   ...
# 168  Sub-Saharan Africa     Tanzania                  34.5
# 169  Sub-Saharan Africa         Togo                  32.2
# 170  Sub-Saharan Africa       Uganda                  25.0
# 171  Sub-Saharan Africa       Zambia                  30.5
# 172  Sub-Saharan Africa     Zimbabwe                  21.3
#
#      GDP per Capita (PPP)
# 0            22947.139795
# 1            37265.812102
# 2            16286.979515
# 3             7295.230136
# 4             9086.060696
# ..                    ...
# 168           2770.681172
# 169           1662.072345
# ...

# %%
gi_ppp_table = gi_ppp.groupby('Region').mean().sort_values('Government Integrity', ascending=False)
gi_ppp_table.round(2)
# Out:
#                               Government Integrity  GDP per Capita (PPP)
# Region
# Europe                                       64.36              39454.89
# Middle East and North Africa                 49.30              33357.50
# Asia-Pacific                                 44.71              18608.47
# Americas                                     43.85              18340.41
# Sub-Saharan Africa                           30.22               4978.50

# %%
sns.lmplot(data=gi_ppp, x='Government Integrity',y='GDP per Capita (PPP)')

# %%
gi_ppp.corr(method='pearson')
# Out:
#                       Government Integrity  GDP per Capita (PPP)
# Government Integrity              1.000000              0.821902
# GDP per Capita (PPP)              0.821902              1.000000

# %%
#investigating government integraty in countries with PPP below US$ 20k
gi_ppp
# Out:
#                  Region Country Name  Government Integrity  \
# 0              Americas    Argentina                  54.0
# 1              Americas      Bahamas                  47.5
# 2              Americas     Barbados                  50.2
# 3              Americas       Belize                  36.3
# 4              Americas      Bolivia                  25.9
# ..                  ...          ...                   ...
# 168  Sub-Saharan Africa     Tanzania                  34.5
# 169  Sub-Saharan Africa         Togo                  32.2
# 170  Sub-Saharan Africa       Uganda                  25.0
# 171  Sub-Saharan Africa       Zambia                  30.5
# 172  Sub-Saharan Africa     Zimbabwe                  21.3
#
#      GDP per Capita (PPP)
# 0            22947.139795
# 1            37265.812102
# 2            16286.979515
# 3             7295.230136
# 4             9086.060696
# ..                    ...
# 168           2770.681172
# 169           1662.072345
# ...

# %%
gi_ppp_grouped = gi_ppp.loc[gi_ppp['GDP per Capita (PPP)'] < 20000]
gi_ppp_corr = gi_ppp_grouped.groupby('Region').mean()

# %%
gi_ppp_corr.corr(method='pearson')
# Out:
#                       Government Integrity  GDP per Capita (PPP)
# Government Integrity               1.00000               0.96106
# GDP per Capita (PPP)               0.96106               1.00000

# %%
sns.lmplot(data=gi_ppp_grouped, x='Government Integrity',y='GDP per Capita (PPP)')

# %%
# Tax Burden x PPP

# %%
countries_region
# Out:
#                  Region Country Name  World Rank  Region Rank  2021 Score  \
# 0              Americas    Argentina       148.0         26.0        52.7
# 1              Americas      Bahamas        70.0         13.0        64.6
# 2              Americas     Barbados        67.0         12.0        65.0
# 3              Americas       Belize       114.0         21.0        57.5
# 4              Americas      Bolivia       172.0         30.0        42.7
# ..                  ...          ...         ...          ...         ...
# 168  Sub-Saharan Africa     Tanzania        93.0          8.0        61.3
# 169  Sub-Saharan Africa         Togo       113.0         18.0        57.5
# 170  Sub-Saharan Africa       Uganda       106.0         14.0        58.6
# 171  Sub-Saharan Africa       Zambia       159.0         39.0        50.4
# 172  Sub-Saharan Africa     Zimbabwe       174.0         46.0        39.5
#
#      Property Rights  Judical Effectiveness  Government Integrity  Tax Burden  \
# ...

# %%
tb_ppp = countries_region[['Region','Country Name','Tax Burden','GDP per Capita (PPP)']]
tb_ppp
# Out:
#                  Region Country Name  Tax Burden  GDP per Capita (PPP)
# 0              Americas    Argentina        70.4          22947.139795
# 1              Americas      Bahamas        97.1          37265.812102
# 2              Americas     Barbados        79.3          16286.979515
# 3              Americas       Belize        78.7           7295.230136
# 4              Americas      Bolivia        85.3           9086.060696
# ..                  ...          ...         ...                   ...
# 168  Sub-Saharan Africa     Tanzania        80.7           2770.681172
# 169  Sub-Saharan Africa         Togo        68.0           1662.072345
# 170  Sub-Saharan Africa       Uganda        73.2           2271.649424
# 171  Sub-Saharan Africa       Zambia        71.1           3623.699395
# 172  Sub-Saharan Africa     Zimbabwe        63.4           2953.484113
#
# [173 rows x 4 columns]

# %%
sns.lmplot(data=tb_ppp, x='Tax Burden',y='GDP per Capita (PPP)')

# %%
tb_ppp.corr(method='pearson')
# Out:
#                       Tax Burden  GDP per Capita (PPP)
# Tax Burden              1.000000             -0.198364
# GDP per Capita (PPP)   -0.198364              1.000000

# %%
tb_ppp_corr = tb_ppp.groupby('Region').mean().sort_values('Tax Burden')
tb_ppp_corr
# Out:
#                               Tax Burden  GDP per Capita (PPP)
# Region
# Europe                         74.195556          39454.894415
# Sub-Saharan Africa             76.413043           4978.500090
# Americas                       78.396667          18340.411191
# Asia-Pacific                   83.215789          18608.471948
# Middle East and North Africa   85.750000          33357.502617

# %%
tb_ppp_corr.corr(method='pearson')
# Out:
#                       Tax Burden  GDP per Capita (PPP)
# Tax Burden              1.000000              0.083964
# GDP per Capita (PPP)    0.083964              1.000000

# %% [markdown]
# # Government Spending x PPP

# %%
gs_ppp = countries_region[['Region','Country Name',"Gov't Spending",'GDP per Capita (PPP)']]
gs_ppp.rename(columns={"Gov't Spending":'GovSpeding'}, inplace=True)
# Out:
# C:\Users\Samsung\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
sns.lmplot(data=gs_ppp, x='GovSpeding',y='GDP per Capita (PPP)')

# %%
gs_ppp.corr(method='pearson')
# Out:
#                       GovSpeding  GDP per Capita (PPP)
# GovSpeding              1.000000             -0.424379
# GDP per Capita (PPP)   -0.424379              1.000000

# %%
gs_ppp = gs_ppp.groupby('Region').mean().sort_values('GovSpeding')
gs_ppp
# Out:
#                               GovSpeding  GDP per Capita (PPP)
# Region
# Europe                         50.060000          39454.894415
# Middle East and North Africa   63.778571          33357.502617
# Asia-Pacific                   73.002632          18608.471948
# Americas                       74.290000          18340.411191
# Sub-Saharan Africa             82.008696           4978.500090

# %% [markdown]
# # Fiscal Health x PPP

# %%
fh_ppp = countries_region[['Region','Country Name',"Fiscal Health",'GDP per Capita (PPP)']]
fh_ppp
# Out:
#                  Region Country Name  Fiscal Health  GDP per Capita (PPP)
# 0              Americas    Argentina           38.4          22947.139795
# 1              Americas      Bahamas           72.7          37265.812102
# 2              Americas     Barbados           79.8          16286.979515
# 3              Americas       Belize           68.5           7295.230136
# 4              Americas      Bolivia           13.4           9086.060696
# ..                  ...          ...            ...                   ...
# 168  Sub-Saharan Africa     Tanzania           90.8           2770.681172
# 169  Sub-Saharan Africa         Togo           89.9           1662.072345
# 170  Sub-Saharan Africa       Uganda           63.2           2271.649424
# 171  Sub-Saharan Africa       Zambia            5.3           3623.699395
# 172  Sub-Saharan Africa     Zimbabwe           58.8           2953.484113
#
# [173 rows x 4 columns]

# %%
sns.lmplot(data=fh_ppp, x='Fiscal Health',y='GDP per Capita (PPP)')

# %%
fh_ppp.corr(method='pearson')
# Out:
#                       Fiscal Health  GDP per Capita (PPP)
# Fiscal Health              1.000000              0.192617
# GDP per Capita (PPP)       0.192617              1.000000

# %%
fh_ppp = fh_ppp.groupby('Region').mean().sort_values('Fiscal Health')
fh_ppp
# Out:
#                               Fiscal Health  GDP per Capita (PPP)
# Region
# Middle East and North Africa      51.428571          33357.502617
# Americas                          66.320000          18340.411191
# Sub-Saharan Africa                67.580435           4978.500090
# Asia-Pacific                      75.300000          18608.471948
# Europe                            88.953333          39454.894415

# %%
fh_ppp.corr(method='pearson')
# Out:
#                       Fiscal Health  GDP per Capita (PPP)
# Fiscal Health              1.000000              0.209951
# GDP per Capita (PPP)       0.209951              1.000000

# %% [markdown]
# # Business Freedom x PPP

# %%
bf_ppp = countries_region[['Region','Country Name',"Business Freedom",'GDP per Capita (PPP)']]
bf_ppp
# Out:
#                  Region Country Name  Business Freedom  GDP per Capita (PPP)
# 0              Americas    Argentina              59.5          22947.139795
# 1              Americas      Bahamas              70.4          37265.812102
# 2              Americas     Barbados              69.7          16286.979515
# 3              Americas       Belize              60.0           7295.230136
# 4              Americas      Bolivia              58.4           9086.060696
# ..                  ...          ...               ...                   ...
# 168  Sub-Saharan Africa     Tanzania              45.7           2770.681172
# 169  Sub-Saharan Africa         Togo              60.6           1662.072345
# 170  Sub-Saharan Africa       Uganda              44.9           2271.649424
# 171  Sub-Saharan Africa       Zambia              66.1           3623.699395
# 172  Sub-Saharan Africa     Zimbabwe              41.5           2953.484113
#
# [173 rows x 4 columns]

# %%
sns.lmplot(data=bf_ppp, x='Business Freedom',y='GDP per Capita (PPP)')

# %%
bf_ppp.corr(method='pearson')
# Out:
#                       Business Freedom  GDP per Capita (PPP)
# Business Freedom               1.00000               0.61373
# GDP per Capita (PPP)           0.61373               1.00000

# %%
bf_ppp = bf_ppp.groupby('Region').mean().sort_values('Business Freedom')
bf_ppp
# Out:
#                               Business Freedom  GDP per Capita (PPP)
# Region
# Sub-Saharan Africa                   51.839130           4978.500090
# Americas                             62.523333          18340.411191
# Asia-Pacific                         68.736842          18608.471948
# Middle East and North Africa         69.485714          33357.502617
# Europe                               73.493333          39454.894415

# %%
bf_ppp.corr(method='pearson')
# Out:
#                       Business Freedom  GDP per Capita (PPP)
# Business Freedom               1.00000               0.90861
# GDP per Capita (PPP)           0.90861               1.00000

# %% [markdown]
# # Labor Freedom

# %%
lf_ppp = countries_region[['Region','Country Name',"Labor Freedom",'GDP per Capita (PPP)']]
lf_ppp
# Out:
#                  Region Country Name  Labor Freedom  GDP per Capita (PPP)
# 0              Americas    Argentina           46.3          22947.139795
# 1              Americas      Bahamas           70.0          37265.812102
# 2              Americas     Barbados           60.1          16286.979515
# 3              Americas       Belize           54.2           7295.230136
# 4              Americas      Bolivia           53.4           9086.060696
# ..                  ...          ...            ...                   ...
# 168  Sub-Saharan Africa     Tanzania           67.7           2770.681172
# 169  Sub-Saharan Africa         Togo           47.1           1662.072345
# 170  Sub-Saharan Africa       Uganda           83.2           2271.649424
# 171  Sub-Saharan Africa       Zambia           45.6           3623.699395
# 172  Sub-Saharan Africa     Zimbabwe           44.1           2953.484113
#
# [173 rows x 4 columns]

# %%
lf_ppp.corr(method='pearson')
# Out:
#                       Labor Freedom  GDP per Capita (PPP)
# Labor Freedom              1.000000              0.293511
# GDP per Capita (PPP)       0.293511              1.000000

# %%
sns.lmplot(data=lf_ppp, x='Labor Freedom',y='GDP per Capita (PPP)')

# %%
lf_ppp = lf_ppp.groupby('Region').mean().sort_values('Labor Freedom')
lf_ppp
# Out:
#                               Labor Freedom  GDP per Capita (PPP)
# Region
# Sub-Saharan Africa                55.700000           4978.500090
# Middle East and North Africa      57.600000          33357.502617
# Americas                          58.530000          18340.411191
# Europe                            61.340000          39454.894415
# Asia-Pacific                      65.868421          18608.471948

# %%
lf_ppp.corr(method='pearson')
# Out:
#                       Labor Freedom  GDP per Capita (PPP)
# Labor Freedom              1.000000              0.258477
# GDP per Capita (PPP)       0.258477              1.000000

# %% [markdown]
# # Monetary Freedom

# %%
mf_ppp = countries_region[['Region','Country Name',"Monetary Freedom",'GDP per Capita (PPP)']]
mf_ppp
# Out:
#                  Region Country Name  Monetary Freedom  GDP per Capita (PPP)
# 0              Americas    Argentina              41.9          22947.139795
# 1              Americas      Bahamas              77.0          37265.812102
# 2              Americas     Barbados              77.3          16286.979515
# 3              Americas       Belize              80.2           7295.230136
# 4              Americas      Bolivia              71.0           9086.060696
# ..                  ...          ...               ...                   ...
# 168  Sub-Saharan Africa     Tanzania              72.9           2770.681172
# 169  Sub-Saharan Africa         Togo              79.7           1662.072345
# 170  Sub-Saharan Africa       Uganda              78.9           2271.649424
# 171  Sub-Saharan Africa       Zambia              71.2           3623.699395
# 172  Sub-Saharan Africa     Zimbabwe               0.0           2953.484113
#
# [173 rows x 4 columns]

# %%
mf_ppp.corr(method='pearson')
# Out:
#                       Monetary Freedom  GDP per Capita (PPP)
# Monetary Freedom              1.000000              0.303281
# GDP per Capita (PPP)          0.303281              1.000000

# %%
sns.lmplot(data=mf_ppp, x='Monetary Freedom',y='GDP per Capita (PPP)')

# %%
mf_ppp = mf_ppp.groupby('Region').mean().sort_values('Monetary Freedom')
mf_ppp
# Out:
#                               Monetary Freedom  GDP per Capita (PPP)
# Region
# Sub-Saharan Africa                   72.091304           4978.500090
# Americas                             73.726667          18340.411191
# Asia-Pacific                         75.668421          18608.471948
# Middle East and North Africa         76.792857          33357.502617
# Europe                               78.973333          39454.894415

# %%
mf_ppp.corr(method='pearson')
# Out:
#                       Monetary Freedom  GDP per Capita (PPP)
# Monetary Freedom               1.00000               0.95776
# GDP per Capita (PPP)           0.95776               1.00000

# %% [markdown]
# # Trade Freedom

# %%
tf_ppp = countries_region[['Region','Country Name',"Trade Freedom",'GDP per Capita (PPP)']]
tf_ppp
# Out:
#                  Region Country Name  Trade Freedom  GDP per Capita (PPP)
# 0              Americas    Argentina           62.6          22947.139795
# 1              Americas      Bahamas           49.0          37265.812102
# 2              Americas     Barbados           58.4          16286.979515
# 3              Americas       Belize           55.0           7295.230136
# 4              Americas      Bolivia           61.6           9086.060696
# ..                  ...          ...            ...                   ...
# 168  Sub-Saharan Africa     Tanzania           64.4           2770.681172
# 169  Sub-Saharan Africa         Togo           65.4           1662.072345
# 170  Sub-Saharan Africa       Uganda           67.4           2271.649424
# 171  Sub-Saharan Africa       Zambia           68.2           3623.699395
# 172  Sub-Saharan Africa     Zimbabwe           56.0           2953.484113
#
# [173 rows x 4 columns]

# %%
tf_ppp.corr(method='pearson')
# Out:
#                       Trade Freedom  GDP per Capita (PPP)
# Trade Freedom              1.000000              0.651704
# GDP per Capita (PPP)       0.651704              1.000000

# %%
sns.scatterplot(data=tf_ppp, x='Trade Freedom',y='GDP per Capita (PPP)')
# Out:
# <AxesSubplot:xlabel='Trade Freedom', ylabel='GDP per Capita (PPP)'>

# %%
tf_ppp = tf_ppp.groupby('Region').mean().sort_values('Trade Freedom')
tf_ppp
# Out:
#                               Trade Freedom  GDP per Capita (PPP)
# Region
# Sub-Saharan Africa                63.113043           4978.500090
# Americas                          68.906667          18340.411191
# Asia-Pacific                      71.657895          18608.471948
# Middle East and North Africa      72.657143          33357.502617
# Europe                            81.817778          39454.894415

# %%
tf_ppp.corr(method='pearson')
# Out:
#                       Trade Freedom  GDP per Capita (PPP)
# Trade Freedom              1.000000              0.928748
# GDP per Capita (PPP)       0.928748              1.000000

# %% [markdown]
# # Investment Freedom

# %%
countries_region
# Out:
#                  Region Country Name  World Rank  Region Rank  2021 Score  \
# 0              Americas    Argentina       148.0         26.0        52.7
# 1              Americas      Bahamas        70.0         13.0        64.6
# 2              Americas     Barbados        67.0         12.0        65.0
# 3              Americas       Belize       114.0         21.0        57.5
# 4              Americas      Bolivia       172.0         30.0        42.7
# ..                  ...          ...         ...          ...         ...
# 168  Sub-Saharan Africa     Tanzania        93.0          8.0        61.3
# 169  Sub-Saharan Africa         Togo       113.0         18.0        57.5
# 170  Sub-Saharan Africa       Uganda       106.0         14.0        58.6
# 171  Sub-Saharan Africa       Zambia       159.0         39.0        50.4
# 172  Sub-Saharan Africa     Zimbabwe       174.0         46.0        39.5
#
#      Property Rights  Judical Effectiveness  Government Integrity  Tax Burden  \
# ...

# %%
countries_region.rename(index={15:'InvestimentFreedom'}, inplace=True)

# %%
#for some reason, pandas didn't return the dataframe using countries_region['Investment Freedom'], so I used Iloc for this job.
if_ppp = countries_region.iloc[:,[0,1,15,26]]
if_ppp
# Out:
#                  Region Country Name  Investment Freedom   \
# 0              Americas    Argentina                 55.0
# 1              Americas      Bahamas                 50.0
# 2              Americas     Barbados                 70.0
# 3              Americas       Belize                 55.0
# 4              Americas      Bolivia                 15.0
# ..                  ...          ...                  ...
# 168  Sub-Saharan Africa     Tanzania                 55.0
# 169  Sub-Saharan Africa         Togo                 60.0
# 170  Sub-Saharan Africa       Uganda                 55.0
# 171  Sub-Saharan Africa       Zambia                 55.0
# 172  Sub-Saharan Africa     Zimbabwe                 25.0
#
#      GDP per Capita (PPP)
# 0            22947.139795
# 1            37265.812102
# 2            16286.979515
# 3             7295.230136
# 4             9086.060696
# ..                    ...
# 168           2770.681172
# 169           1662.072345
# ...

# %%
if_ppp.corr(method='pearson')
# Out:
#                       Investment Freedom   GDP per Capita (PPP)
# Investment Freedom               1.000000              0.536391
# GDP per Capita (PPP)             0.536391              1.000000

# %%
#seaborn also wasn't able to get the investment freedom column, so I stored the x and y axis into variable and pass them to seaborn 
x_graf = if_ppp.iloc[:,2]
y_graf = if_ppp.iloc[:,3]
x_graf
y_graf
# Out:
# 0      22947.139795
# 1      37265.812102
# 2      16286.979515
# 3       7295.230136
# 4       9086.060696
#            ...
# 168     2770.681172
# 169     1662.072345
# 170     2271.649424
# 171     3623.699395
# 172     2953.484113
# Name: GDP per Capita (PPP), Length: 173, dtype: float64

# %%
sns.scatterplot(data=if_ppp, x=x_graf,y=y_graf)
# Out:
# <AxesSubplot:xlabel='Investment Freedom ', ylabel='GDP per Capita (PPP)'>

# %%
if_ppp = if_ppp.groupby('Region').mean().sort_values('GDP per Capita (PPP)')
if_ppp
# Out:
#                               Investment Freedom   GDP per Capita (PPP)
# Region
# Sub-Saharan Africa                      50.543478           4978.500090
# Americas                                62.000000          18340.411191
# Asia-Pacific                            44.736842          18608.471948
# Middle East and North Africa            53.928571          33357.502617
# Europe                                  73.888889          39454.894415

# %%
if_ppp.corr(method='pearson')
# Out:
#                       Investment Freedom   GDP per Capita (PPP)
# Investment Freedom               1.000000              0.637018
# GDP per Capita (PPP)             0.637018              1.000000

# %% [markdown]
# # Financial Freedom

# %%
ff_ppp = countries_region[['Region','Country Name',"Financial Freedom",'GDP per Capita (PPP)']]
ff_ppp
# Out:
#                  Region Country Name  Financial Freedom  GDP per Capita (PPP)
# 0              Americas    Argentina               60.0          22947.139795
# 1              Americas      Bahamas               60.0          37265.812102
# 2              Americas     Barbados               60.0          16286.979515
# 3              Americas       Belize               50.0           7295.230136
# 4              Americas      Bolivia               40.0           9086.060696
# ..                  ...          ...                ...                   ...
# 168  Sub-Saharan Africa     Tanzania               50.0           2770.681172
# 169  Sub-Saharan Africa         Togo               30.0           1662.072345
# 170  Sub-Saharan Africa       Uganda               40.0           2271.649424
# 171  Sub-Saharan Africa       Zambia               50.0           3623.699395
# 172  Sub-Saharan Africa     Zimbabwe               10.0           2953.484113
#
# [173 rows x 4 columns]

# %%
ff_ppp.corr(method='pearson')
# Out:
#                       Financial Freedom  GDP per Capita (PPP)
# Financial Freedom              1.000000              0.652337
# GDP per Capita (PPP)           0.652337              1.000000

# %%
sns.lmplot(data=ff_ppp, x='Financial Freedom',y='GDP per Capita (PPP)')

# %%
ff_ppp = ff_ppp.groupby('Region').mean().sort_values('Financial Freedom')
ff_ppp
# Out:
#                               Financial Freedom  GDP per Capita (PPP)
# Region
# Sub-Saharan Africa                    39.782609           4978.500090
# Asia-Pacific                          41.578947          18608.471948
# Americas                              51.000000          18340.411191
# Middle East and North Africa          52.857143          33357.502617
# Europe                                62.666667          39454.894415

# %%
ff_ppp.corr(method='pearson')
# Out:
#                       Financial Freedom  GDP per Capita (PPP)
# Financial Freedom              1.000000              0.898223
# GDP per Capita (PPP)           0.898223              1.000000
